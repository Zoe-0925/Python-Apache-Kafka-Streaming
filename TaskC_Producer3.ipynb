# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import pandas as pd
import numpy as np


 
def publish_message(producer_instance, topic_name, data):
    try:
        value_bytes = bytes(data, encoding='utf-8')
        producer_instance.send(topic_name, value=value_bytes)
        print('Message published successfully. ' + data)
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['127.0.0.1:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'Scenario03'
    print('Publishing records..')
    producer03 = connect_kafka_producer()
    
    for e in range(10000):
        df = pd.read_csv("/Users/jessie/Desktop/Assignment Data-20190520/hotspot_TERRA_streaming.csv")
        df_random = dict(df.loc[np.random.choice(df.index)])
        df_random['sender_id'] = 'producer3'
        df_random['created_time'] = dt.datetime.now().strftime("%X")
        
        data = "data:" + str(df_random)
        publish_message(producer03, topic, data)
        
        a = random.randint(10,30)
        sleep(a)
# Out:
# Publishing records..
# Message published successfully. data:{'latitude': -36.8922, 'longitude': 145.1252, 'confidence': 60.0, 'surface_temperature_celcius': 40.0, 'sender_id': 'producer3', 'created_time': '23:32:35'}
# Message published successfully. data:{'latitude': -34.7979, 'longitude': 141.5966, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'sender_id': 'producer3', 'created_time': '23:32:52'}
# Message published successfully. data:{'latitude': -36.239000000000004, 'longitude': 143.3972, 'confidence': 100.0, 'surface_temperature_celcius': 116.0, 'sender_id': 'producer3', 'created_time': '23:35:18'}
# Message published successfully. data:{'latitude': -37.7361, 'longitude': 145.335, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'sender_id': 'producer3', 'created_time': '23:35:37'}
# ...
